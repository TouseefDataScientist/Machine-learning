# %% [markdown]
# # Muhammad Talha Nazeer
#
# **📞 Phone:** +92 316 5301997
# **📧 E-mail:** [talhanazeer113@gmail.com](mailto:talhanazeer113@gmail.com)
# **🔗 GitHub:** [https://github.com/talha-nazeer](https://github.com/talha-nazeer)
# **🔗 LinkedIn:** [linkedin.com/in/talha-nazeer-b2b03927a](https://linkedin.com/in/talha-nazeer-b2b03927a)
# **🏠 Purpose:** Titanic Project

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading Dataset
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Removing Name, Ticket, Cabin Columns

# %%
titanic = titanic.drop(['Name', 'Ticket', 'Cabin'], axis=1)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %% [markdown]
# # Data Wrangling

# %%
# Null Values
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
#Fill Null values in Age
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)
# Out:
# C:\Users\E-TIME\AppData\Local\Temp\ipykernel_8696\2184073557.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Age'].fillna(titanic['Age'].median(), inplace=True)

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
#Fill Null values in Embarked using mode
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
# No Null Values
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#No Duplicates
titanic.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#Replacing male with 0 and female with in Gender
titanic['Sex'].replace({'male': 0, 'female': 1}, inplace=True)
# Out:
# C:\Users\E-TIME\AppData\Local\Temp\ipykernel_8696\3433729414.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic['Sex'].replace({'male': 0, 'female': 1}, inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    0  22.0      1      0   7.2500        S
# 1              2         1       1    1  38.0      1      0  71.2833        C
# 2              3         1       3    1  26.0      0      0   7.9250        S
# 3              4         1       1    1  35.0      1      0  53.1000        S
# 4              5         0       3    0  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    0  27.0      0      0  13.0000        S
# 887          888         1       1    1  19.0      0      0  30.0000        S
# 888          889         0       3    1  28.0      1      2  23.4500        S
# 889          890         1       1    0  26.0      0      0  30.0000        C
# 890          891         0       3    0  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# Create new column of comparison making comparison of age and fare
titanic['Comparison'] = ['Young and Rich' if (age < 30 and fare > 10) else 'Older and Poor' for age, fare in zip(titanic['Age'], titanic['Fare'])]

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    0  22.0      1      0   7.2500        S
# 1              2         1       1    1  38.0      1      0  71.2833        C
# 2              3         1       3    1  26.0      0      0   7.9250        S
# 3              4         1       1    1  35.0      1      0  53.1000        S
# 4              5         0       3    0  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    0  27.0      0      0  13.0000        S
# 887          888         1       1    1  19.0      0      0  30.0000        S
# 888          889         0       3    1  28.0      1      2  23.4500        S
# 889          890         1       1    0  26.0      0      0  30.0000        C
# 890          891         0       3    0  32.0      0      0   7.7500        Q
#
#          Comparison
# ...

# %%
x = titanic['Age']
y = titanic['Fare']

# %%
plt.scatter(x, y, edgecolor='green' ,color='red')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
colors= ['green' if age > 40 else 'red' for age in x]
plt.scatter(x,y, color= colors)

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()

# %%
color = [
    'red' if age > 65 else 
    'green' if age > 55 else 
    'blue' if age > 45 else 
    'black' if age > 35 else 
    'brown' if age > 25 else 
    'pink' if age > 15 else 
    'yellow' if age > 5 else 
    'purple'  
    for age in x
]

# Scatter plot with color argument corrected
plt.scatter(x, y, c=color)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()

# %%
plt.bar(x,y, color=['red', 'green', 'blue'])
plt.show()

# %%
class_counts = titanic['Pclass'].value_counts()

class_counts.plot(kind='bar', color=['blue', 'green', 'red'])

plt.xlabel('Passenger class')
plt.ylabel('Number of passengers')
plt.title('Number of passenger by class')

plt.show()

# %%
# Get unique classes from the dataset, ensuring proper order
unique_classes = sorted(titanic['Pclass'].unique())

# Get the counts for each class in the same order
class_counts = [titanic[titanic['Pclass'] == cls].shape[0] for cls in unique_classes]

# Define labels and colors dynamically
labels = [f"Class {cls}" for cls in unique_classes]
colors = ['blue', 'green', 'red']

# Create the pie chart
plt.pie(class_counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Add a title
plt.title('Number of Passengers by Class')

# Display the chart
plt.show()

# %%
class_counts = titanic['Survived'].value_counts()

class_counts.plot(kind='bar', color=['red', 'green'])


plt.ylabel('Number of passengers')
plt.title('Survived vs Non Survived')
plt.xticks(ticks=(0, 1), labels=['Non-Survived', 'Survived'])
plt.show()
