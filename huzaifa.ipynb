# %% [markdown]
# <center>
#
# ### Name: Huzaifa Dad
# ### Email: huzaifadad.abt@gmail.com
# ### Github: https://github.com/HuzaifaDad
# ### Purpose of Document: Practicing of reading and loading different files
# </center>

# %% [markdown]
# ##### Process to read docx file
# ##### Installing Library

# %%
#installing Library
# %pip install python-docx
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 699.1 kB/s eta 0:00:05
#    -------- ------------------------------- 0.8/3.8 MB 845.5 kB/s eta 0:00:04
#    ---------- ----------------------------- 1.0/3.8 MB 955.9 kB/s eta 0:00:03
#    ------------- -------------------------- 1.3/3.8 MB 1.0 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/3.8 MB 1.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 1.6/3.8 MB 966.7 kB/s eta 0:00:03
#    ------------------- -------------------- 1.8/3.8 MB 903.0 kB/s eta 0:00:03
#    ------------------- -------------------- 1.8/3.8 MB 903.0 kB/s eta 0:00:03
#    ------------------- -------------------- 1.8/3.8 MB 903.0 kB/s eta 0:00:03
# ...

# %% [markdown]
# ##### import libraries

# %%
#import pandas library
import pandas as pd

# %%
#import python-docx library
from docx import Document

# %% [markdown]
# ##### Load docx file

# %%
#load the document file
doc = Document('practice_doc.docx')

# %% [markdown]
# ##### Extract docx file

# %%
#Extract text from all paragraphs
text_data = [para.text for para in doc.paragraphs]

# %% [markdown]
# ##### Display Docx file

# %%
#print the extracted text
print(text_data)
# Out:
# ['Title:  Huzaifa Practice File', '', 'I am practicing of reading and loading different files in python jupyter notebook…']

# %% [markdown]
# ##### import libraries

# %%
#import pandas library
import pandas as pd

# %%
#import python-docx library
from docx import Document

# %% [markdown]
# ##### Read the Docx file

# %%
#loading docx file
doc = Document('practice_doc.docx')

# %% [markdown]
# ##### Extract text from Docx file

# %%
#Extract text from docx file
text_data = [para.text for para in doc.paragraphs]

# %% [markdown]
# ##### Load and Display dataframe without column name

# %%
#create dataframe with extracted text
df = pd.DataFrame(text_data)
print(df)
# Out:
#                                                    0
# 0                      Title:  Huzaifa Practice File
# 1
# 2  I am practicing of reading and loading differe...

# %% [markdown]
# ##### Load and Display dataframe with column name

# %%
#create dataframe with extracted text
df = pd.DataFrame(text_data, columns=["Text"])
print(df)
# Out:
#                                                 Text
# 0                      Title:  Huzaifa Practice File
# 1
# 2  I am practicing of reading and loading differe...

# %% [markdown]
# ##### Process to read pdf file
# ##### Installing Library

# %%
# %pip install pdfplumber
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### import libraries

# %%
#import pandas library
import pandas as pd

# %%
#import pdfplumber library
import pdfplumber

# %% [markdown]
# ##### Open pdf file

# %%
pdf = pdfplumber.open('Artistry_Hub_presentation.pdf')

# %% [markdown]
# ##### Extract text from pdf pages

# %%
extracted_text = [page.extract_text() for page in pdf.pages]

# %% [markdown]
# ##### Load extracted text to dataframe

# %%
df = pd.DataFrame(extracted_text, columns=["Text"])

# %% [markdown]
# ##### Display pdf text in dataframe

# %%
print(df)
# Out:
#                                                  Text
# 0   ARTISTRY HUB\nPROJECT TITLE:\nARTISTRY HUB\nGr...
# 1   ARTISTRY HUB\nINTRODUCTION\n01.\n• Artistry Hu...
# 2   ARTISTRY HUB\n02. PROBLEM STATEMENT\n• In toda...
# 3   ARTISTRY HUB\n03. PROPOSED SOLUTION\n• Provide...
# 4   ARTISTRY HUB\nFeatures:\nArt Gallery Creation\...
# 5   ARTISTRY HUB\nFeatures:\nPersonalized\nReal-ti...
# 6   ARTISTRY HUB\nFeatures:\nBidding\nPayment Meth...
# 7                                        ARTISTRY HUB
# 8   ARTISTRY HUB\n05. TECHNOLOGIES & TOOLS:\n• Fro...
# 9   ARTISTRY HUB\n06. API’s & Libraries:\n• API’s:...
# 10  ARTISTRY HUB\n07. Hardware Requirements:\n• Pr...
# 11                           ARTISTRY HUB\nTHANK\nYOU

# %% [markdown]
# ##### Process to read Json file

# %% [markdown]
# ##### Import Library

# %%
#import pandas library
import pandas as pd

# %%
#import json library
import json
from pandas import json_normalize

# %% [markdown]
# ##### Load json file

# %%
df = pd.read_json('json_practice_file.json')
print(df)
# Out:
#       name  age  is_student                   courses
# 0  Huzaifa   30       False  [Math, Science, History]
# 1   Nabeel   28        True            [English, Art]
# 2  Arsalan   35       False      [Biology, Chemistry]

# %% [markdown]
# ##### Process to read txt file

# %% [markdown]
# ##### Import Libraries

# %%
#import pandas library
import pandas as pd

# %% [markdown]
# ##### Read and Load txt file

# %%
df = pd.read_csv('practice_text_file.txt')
print(df)
# Out:
#                                                    Huzaifa Dad is a 23-year-old Software Developer from Rawalpindi  \
# He enjoys reading                                                                           traveling
# His favorite food is Biryani                                      and his favorite sport is Cricket.
# Huzaifa dreams of becoming a Data Scientist          as he is passionate about using technology to...
# His ambition is to create impactful solutions t...                                                NaN
# He believes that with the right skills and dete...
# he can help build technology that improves live...                                                NaN
#
#                                                                         Pakistan.
# He enjoys reading                                    and coding in his free time.
# His favorite food is Biryani                                                  NaN
# ...

# %% [markdown]
# ##### Process to read csv file

# %% [markdown]
# ##### import library

# %%
#import pandas
import pandas as pd

# %% [markdown]
# ##### Load and read csv file

# %%
df = pd.read_csv('dummy_dataset_2.csv')
print(df)
# Out:
#        Month         Day Price Net Price
# 0     January     Monday    79        82
# 1    February    Tuesday   101       101
# 2       March  Wednesday    67        49
# 3       April   Thursday   non        89
# 4         non     Friday   100        53
# 5        June   Saturday    46        54
# 6        July     Sunday   105        81
# 7      August     Monday    57        96
# 8   September    Tuesday    75       109
# 9     October        non    88        83
# 10   November   Thursday    70       non
# 11   December     Friday   104        63
# 12    January   Saturday    62        43
# 13   February     Sunday    59        94
# 14        non     Monday    69        51
# 15      April    Tuesday    61        62
# 16        May  Wednesday    81       non
# 17       June   Thursday    46       106
# 18       July        non    66       100
# 19     August   Saturday   101        69
# 20  September     Sunday    98        94
# 21    October     Monday    66       110
# ...

# %% [markdown]
# ##### Process to read excel file

# %% [markdown]
# ##### Install Library

# %%
# %pip install openpyxl
# Out:
# ...
#
# ...

# %% [markdown]
# ##### Import libraries

# %%
#import pandas
import pandas as pd

# %%
#import openpyxl
import openpyxl

# %% [markdown]
# ##### Load and read excel file

# %%
df = pd.read_excel('dummy_dataset.xlsx')
print(df)
# Out:
#        Month         Day Price Net Price
# 0     January     Monday    79        82
# 1    February    Tuesday   101       101
# 2       March  Wednesday    67        49
# 3       April   Thursday   non        89
# 4         non     Friday   100        53
# 5        June   Saturday    46        54
# 6        July     Sunday   105        81
# 7      August     Monday    57        96
# 8   September    Tuesday    75       109
# 9     October        non    88        83
# 10   November   Thursday    70       non
# 11   December     Friday   104        63
# 12    January   Saturday    62        43
# 13   February     Sunday    59        94
# 14        non     Monday    69        51
# 15      April    Tuesday    61        62
# 16        May  Wednesday    81       non
# 17       June   Thursday    46       106
# 18       July        non    66       100
# 19     August   Saturday   101        69
# 20  September     Sunday    98        94
# 21    October     Monday    66       110
# ...
