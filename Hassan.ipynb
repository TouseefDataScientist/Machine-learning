# %% [markdown]
# <center style="color: red">Name: Hassan Abbas <br></center><br>
# <center style="color:yellow">Email: hassanabbasaiengineer@gmail.com<br></center><br>
# <center style="color:green">Github:https://github.com/HassanEng118<br>
# Purpose of Documents: For implementation a small datasets</center>

# %%
# loading libraries
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing library
import pandas as pd

# %% [markdown]
# # **loading datasets**

# %%
#loading csv files
pd.read_csv("data.csv")
# Out:
#              Name Designation  Gender     Age     Salary
# 0         Mukhtar   professor        M   37.0   115000.0
# 1            Aziz      Teacher       M   30.0    35000.0
# 2          Mohsin     Engineer       M   29.0    50000.0
# 3   Naveed Fatima     Analyst        F   30.0    70000.0
# 4           Babar     Engineer       M   25.0  1500000.0
# 5            Aqsa     Scienist       F   22.0        NaN
# 6           Rafia     Analyst        F   29.0    20000.0
# 7           Samra    Scientist       F   26.0   115000.0
# 8            Eman     Engineer       F   28.0    35000.0
# 9        Abdullah      Teacher       M   55.0        NaN
# 10          Mosib   professor        M   60.0        NaN
# 11          Ahmed     engineer       M    NaN        NaN
# 12          Ahsan      trainer       M  156.0    90000.0
# 13          Wajid      teacher       M   67.0   110000.0
# 14          Naeen      trainer       M   80.0    16000.0
# ...

# %%
df=pd.read_csv("data.csv")

# %%
print(df)
# Out:
#              Name Designation  Gender     Age     Salary
# 0         Mukhtar   professor        M   37.0   115000.0
# 1            Aziz      Teacher       M   30.0    35000.0
# 2          Mohsin     Engineer       M   29.0    50000.0
# 3   Naveed Fatima     Analyst        F   30.0    70000.0
# 4           Babar     Engineer       M   25.0  1500000.0
# 5            Aqsa     Scienist       F   22.0        NaN
# 6           Rafia     Analyst        F   29.0    20000.0
# 7           Samra    Scientist       F   26.0   115000.0
# 8            Eman     Engineer       F   28.0    35000.0
# 9        Abdullah      Teacher       M   55.0        NaN
# 10          Mosib   professor        M   60.0        NaN
# 11          Ahmed     engineer       M    NaN        NaN
# 12          Ahsan      trainer       M  156.0    90000.0
# 13          Wajid      teacher       M   67.0   110000.0
# 14          Naeen      trainer       M   80.0    16000.0
# ...

# %%
df
# Out:
#              Name Designation  Gender     Age     Salary
# 0         Mukhtar   professor        M   37.0   115000.0
# 1            Aziz      Teacher       M   30.0    35000.0
# 2          Mohsin     Engineer       M   29.0    50000.0
# 3   Naveed Fatima     Analyst        F   30.0    70000.0
# 4           Babar     Engineer       M   25.0  1500000.0
# 5            Aqsa     Scienist       F   22.0        NaN
# 6           Rafia     Analyst        F   29.0    20000.0
# 7           Samra    Scientist       F   26.0   115000.0
# 8            Eman     Engineer       F   28.0    35000.0
# 9        Abdullah      Teacher       M   55.0        NaN
# 10          Mosib   professor        M   60.0        NaN
# 11          Ahmed     engineer       M    NaN        NaN
# 12          Ahsan      trainer       M  156.0    90000.0
# 13          Wajid      teacher       M   67.0   110000.0
# 14          Naeen      trainer       M   80.0    16000.0
# ...

# %%
# %pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel("data.xlsx")
# Out:
#              Name Designation  Gender     Age     Salary
# 0         Mukhtar   professor        M   37.0    11500.0
# 1            Aziz      Teacher       M   30.0    35000.0
# 2          Mohsin     Engineer       M   29.0    50000.0
# 3   Naveed Fatima     Analyst        F   30.0    70000.0
# 4           Babar     Engineer       M   25.0  1500000.0
# 5            Aqsa     Scienist       F   22.0        NaN
# 6           Rafia     Analyst        F   29.0    20000.0
# 7           Samra    Scientist       F   26.0   115000.0
# 8            Eman     Engineer       F   28.0    35000.0
# 9        Abdullah      Teacher       M   55.0        NaN
# 10          Mosib   professor        M   60.0        NaN
# 11          Ahmed     engineer       M    NaN        NaN
# 12          Ahsan      trainer       M  156.0        NaN
# 13          Wajid      teacher       M   67.0        NaN
# 14          Naeen      trainer       M   80.0        NaN
# ...

# %%
df.head()
# Out:
#             Name Designation  Gender    Age     Salary
# 0        Mukhtar   professor        M  37.0   115000.0
# 1           Aziz      Teacher       M  30.0    35000.0
# 2         Mohsin     Engineer       M  29.0    50000.0
# 3  Naveed Fatima     Analyst        F  30.0    70000.0
# 4          Babar     Engineer       M  25.0  1500000.0

# %%
df.dead(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8824\489612790.py in ?()
# ----> 1 df.dead(1)
#
# c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dead'

# %%
df.head(1)
# Out:
#       Name Designation  Gender    Age    Salary
# 0  Mukhtar   professor        M  37.0  115000.0

# %%
df.tail()
# Out:
#       Name Designation  Gender     Age    Salary
# 12   Ahsan      trainer       M  156.0   90000.0
# 13   Wajid      teacher       M   67.0  110000.0
# 14   Naeen      trainer       M   80.0   16000.0
# 15  Qaisar   professor        M   20.0  170000.0
# 16   Wajid     Engineer       M   85.0  190000.0

# %%
df.tail(2)
# Out:
#       Name Designation  Gender    Age    Salary
# 15  Qaisar   professor        M  20.0  170000.0
# 16   Wajid     Engineer       M  85.0  190000.0

# %%
df.between_time()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.between_time()
#
# TypeError: NDFrame.between_time() missing 2 required positional arguments: 'start_time' and 'end_time'

# %%
df.iloc(10:12)
# Out:
#   Cell In[22], line 1
#     df.iloc(10:12)
#               ^
# SyntaxError: invalid syntax

# %%
df.iloc(9)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 9
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8824\1226264574.py in ?()
# ----> 1 df.iloc(9)
#
# c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# ...

# %%
df.iloc [10:12]
# Out:
#      Name Designation  Gender    Age  Salary
# 10  Mosib   professor        M  60.0     NaN
# 11  Ahmed     engineer       M   NaN     NaN

# %%
df.iloc[10]
# Out:
# Name                 Mosib
# Designation     professor
# Gender                   M
# Age                   60.0
# Salary                 NaN
# Name: 10, dtype: object
