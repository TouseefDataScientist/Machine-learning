# %%
import pandas 
import pandas as pd
pd.read_csv("data2.csv")
# Out:
#          Days  phy  MATH  CHEM  TOTAL
# 0      Monday   56    52    76    184
# 1     Tuesday   64    96    60    220
# 2   Wednesday   36    63    70    169
# 3    Thursday    9    11    32     52
# 4      Friday   69   100    94    263
# 5    Saturday    3    99    88    190
# 6      Sunday    0    39    30     69
# 7      Monday   20    96    60    176
# 8     Tuesday   13    89    61    163
# 9   Wednesday   82    49    76    207
# 10   Thursday   78    44    52    174
# 11     Friday   97    26    45    168
# 12   Saturday   49    70    86    205
# 13     Sunday   57    99    31    187
# 14     Monday   15    37    88    140
# 15    Tuesday  100    33    81    214
# 16  Wednesday  100    20    47    167

# %%
df=pd.read_csv("data2.csv")
print(df)
# Out:
#          Days  phy  MATH  CHEM  TOTAL
# 0      Monday   56    52    76    184
# 1     Tuesday   64    96    60    220
# 2   Wednesday   36    63    70    169
# 3    Thursday    9    11    32     52
# 4      Friday   69   100    94    263
# 5    Saturday    3    99    88    190
# 6      Sunday    0    39    30     69
# 7      Monday   20    96    60    176
# 8     Tuesday   13    89    61    163
# 9   Wednesday   82    49    76    207
# 10   Thursday   78    44    52    174
# 11     Friday   97    26    45    168
# 12   Saturday   49    70    86    205
# 13     Sunday   57    99    31    187
# 14     Monday   15    37    88    140
# 15    Tuesday  100    33    81    214
# 16  Wednesday  100    20    47    167

# %%
df.describe()
# Out:
#               phy        MATH       CHEM       TOTAL
# count   17.000000   17.000000  17.000000   17.000000
# mean    49.882353   60.176471  63.352941  173.411765
# std     35.124568   31.105135  21.280687   50.932626
# min      0.000000   11.000000  30.000000   52.000000
# 25%     15.000000   37.000000  47.000000  167.000000
# 50%     56.000000   52.000000  61.000000  176.000000
# 75%     78.000000   96.000000  81.000000  205.000000
# max    100.000000  100.000000  94.000000  263.000000

# %%
df.shape
# Out:
# (17, 5)

# %%
printdata=pd.read_csv("data2.csv")
print("printdata")
# Out:
# printdata

# %%
print("printdata")
# Out:
# printdata

# %%
df.shape
# Out:
# (17, 5)

# %%
df['Designation']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Designation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['Designation']
#
# ...

# %%
df.isnull().sum()
# Out:
# Days     0
# phy      0
# MATH     0
# CHEM     0
# TOTAL    0
# dtype: int64

# %%
df['age'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['age'].isnull().sum()
#
# ...

# %%
df['phy'].isnull().sum()
# Out:
# np.int64(0)

# %%
#replacing null value
df['phy']=df['phy'].fillna(df['phy'].median())

# %%
df['phy'].isnull().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd
pd.read_csv("data2.csv")
# Out:
#          Days    phy  MATH  CHEM  TOTAL
# 0      Monday    NaN    52    76    184
# 1     Tuesday   64.0    96    60    220
# 2   Wednesday   36.0    63    70    169
# 3    Thursday    9.0    11    32     52
# 4      Friday   69.0   100    94    263
# 5    Saturday    3.0    99    88    190
# 6      Sunday    0.0    39    30     69
# 7      Monday   20.0    96    60    176
# 8     Tuesday   13.0    89    61    163
# 9   Wednesday   82.0    49    76    207
# 10   Thursday    NaN    44    52    174
# 11     Friday   97.0    26    45    168
# 12   Saturday   49.0    70    86    205
# 13     Sunday   57.0    99    31    187
# 14     Monday   15.0    37    88    140
# 15    Tuesday  100.0    33    81    214
# 16  Wednesday  100.0    20    47    167

# %%
pd.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.describe()
#
# AttributeError: module 'pandas' has no attribute 'describe'

# %%
df=pd.read_csv('data2.csv')
df.describe()
# Out:
#               phy        MATH       CHEM       TOTAL
# count   15.000000   17.000000  17.000000   17.000000
# mean    47.600000   60.176471  63.352941  173.411765
# std     36.677747   31.105135  21.280687   50.932626
# min      0.000000   11.000000  30.000000   52.000000
# 25%     14.000000   37.000000  47.000000  167.000000
# 50%     49.000000   52.000000  61.000000  176.000000
# 75%     75.500000   96.000000  81.000000  205.000000
# max    100.000000  100.000000  94.000000  263.000000

# %%
df['designation']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'designation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['designation']
#
# ...
