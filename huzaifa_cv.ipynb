# %% [markdown]
# <center>
#
# # **Huzaifa Dad**
# |[Email](huzaifadad.abt@gmail.com)|[GitHub](https://github.com/HuzaifaDad)|[LinkedIn](https://www.linkedin.com/in/huzaifa-dad)
# ### Laravel Developer
# </center>
#
# ___
#
# ### <u> **PROFILE**</u>
# - I am a skilled full stack developer. I can work with html,css,bootstrap,javascript,MYSQL,core PHP and laravel. I have better understanding of progrmming logical concept like oop ,mvc .
#
# - I am the student of bachelors in Govt. Gordon college rawalpindi. I am doing BS in IT. I have also done web development course from azad chaiwala institute.
# ___
#
# ### <u>**EDUCATION**</u>
# ##### **Govt. High School Jarral Abbottabad**
# - 2016 to 2018:
# - Matric in Science
# ___
#
# ##### **Govt. Gordon college Rawalpindi**
# - April 2019 to April 2021:
# - Intermediate im I.C.S
# ___
#
# ##### **Govt. Gordon college Rawalpindi**
# - April 2021 to present:
# - Bachelors in Information Technology(on going)
# ___
#
# ### <u>**EXPERIENCE**</u>
# - I have 6 months of hands on experience in web development.
# ___
#
# ##### <u>**MY Projects**</u>
# - I create many projects in core PHP like weather website, Todo website, book management system with picture and full validation.
# - I also developed an inventory management system in Laravel.
# ___
#
# ##### <u>**SKILLS**</u>
#
# 1. Web Developer
# 2. Software Developer
# 3. Laravel Developer
# 4. Clean and readable coding style
# 5. Logical understanding of code
# 6. Collaborative with team
# 7. Communication
# 8. Problem solving
