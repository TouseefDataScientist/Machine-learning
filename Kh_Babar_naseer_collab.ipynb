# %% [markdown]
# <a href="https://colab.research.google.com/github/TouseefDataScientist/Machine-learning/blob/main/Kh_Babar_naseer_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 Minutes to Pandas

# %%
import pandas as pd
import numpy as np

# %%
data = {'col1': np.random.rand(20), 'col2': np.random.randint(0, 100, 20)}
df = pd.DataFrame(data)
df
# Out:
#         col1  col2
# 0   0.062312    72
# 1   0.527411    46
# 2   0.927956    44
# 3   0.704199    92
# 4   0.266561    42
# 5   0.811416    75
# 6   0.869957    31
# 7   0.552545    75
# 8   0.912127    29
# 9   0.912776    23
# 10  0.416291    19
# 11  0.742034    41
# 12  0.744020     0
# 13  0.311510    33
# 14  0.315737    91
# 15  0.965141    99
# 16  0.482071    85
# 17  0.541128    87
# 18  0.571122    59
# 19  0.203215    31

# %%
df.head()
# Out:
#        col1  col2
# 0  0.062312    72
# 1  0.527411    46
# 2  0.927956    44
# 3  0.704199    92
# 4  0.266561    42

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of         col1  col2
# 0   0.062312    72
# 1   0.527411    46
# 2   0.927956    44
# 3   0.704199    92
# 4   0.266561    42
# 5   0.811416    75
# 6   0.869957    31
# 7   0.552545    75
# 8   0.912127    29
# 9   0.912776    23
# 10  0.416291    19
# 11  0.742034    41
# 12  0.744020     0
# 13  0.311510    33
# 14  0.315737    91
# 15  0.965141    99
# 16  0.482071    85
# 17  0.541128    87
# 18  0.571122    59
# 19  0.203215    31>

# %%
df.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
df.describe()
# Out:
#             col1       col2
# count  20.000000  20.000000
# mean    0.591976  53.700000
# std     0.270032  28.855539
# min     0.062312   0.000000
# 25%     0.391153  31.000000
# 50%     0.561833  45.000000
# 75%     0.826051  77.500000
# max     0.965141  99.000000

# %%
df.T
# Out:
#              0          1          2          3          4          5   \
# col1   0.062312   0.527411   0.927956   0.704199   0.266561   0.811416
# col2  72.000000  46.000000  44.000000  92.000000  42.000000  75.000000
#
#              6          7          8          9          10         11  \
# col1   0.869957   0.552545   0.912127   0.912776   0.416291   0.742034
# col2  31.000000  75.000000  29.000000  23.000000  19.000000  41.000000
#
#            12        13         14         15         16         17  \
# col1  0.74402   0.31151   0.315737   0.965141   0.482071   0.541128
# col2  0.00000  33.00000  91.000000  99.000000  85.000000  87.000000
#
#              18         19
# col1   0.571122   0.203215
# col2  59.000000  31.000000

# %%
df.sort_values(by='col1')
# Out:
#         col1  col2
# 0   0.062312    72
# 19  0.203215    31
# 4   0.266561    42
# 13  0.311510    33
# 14  0.315737    91
# 10  0.416291    19
# 16  0.482071    85
# 1   0.527411    46
# 17  0.541128    87
# 7   0.552545    75
# 18  0.571122    59
# 3   0.704199    92
# 11  0.742034    41
# 12  0.744020     0
# 5   0.811416    75
# 6   0.869957    31
# 8   0.912127    29
# 9   0.912776    23
# 2   0.927956    44
# 15  0.965141    99

# %%
df['col2']
# Out:
# 0     72
# 1     46
# 2     44
# 3     92
# 4     42
# 5     75
# 6     31
# 7     75
# 8     29
# 9     23
# 10    19
# 11    41
# 12     0
# 13    33
# 14    91
# 15    99
# 16    85
# 17    87
# 18    59
# 19    31
# Name: col2, dtype: int64

# %%
df.iloc[3
        ]
# Out:
# col1     0.704199
# col2    92.000000
# Name: 3, dtype: float64

# %%
df.mean()
# Out:
# col1     0.591976
# col2    53.700000
# dtype: float64

# %%
df
# Out:
#         col1  col2
# 0   0.062312    72
# 1   0.527411    46
# 2   0.927956    44
# 3   0.704199    92
# 4   0.266561    42
# 5   0.811416    75
# 6   0.869957    31
# 7   0.552545    75
# 8   0.912127    29
# 9   0.912776    23
# 10  0.416291    19
# 11  0.742034    41
# 12  0.744020     0
# 13  0.311510    33
# 14  0.315737    91
# 15  0.965141    99
# 16  0.482071    85
# 17  0.541128    87
# 18  0.571122    59
# 19  0.203215    31

# %%
df.median()
# Out:
# col1     0.561833
# col2    45.000000
# dtype: float64

# %%
df.transpose()
# Out:
#              0          1          2          3          4          5   \
# col1   0.062312   0.527411   0.927956   0.704199   0.266561   0.811416
# col2  72.000000  46.000000  44.000000  92.000000  42.000000  75.000000
#
#              6          7          8          9          10         11  \
# col1   0.869957   0.552545   0.912127   0.912776   0.416291   0.742034
# col2  31.000000  75.000000  29.000000  23.000000  19.000000  41.000000
#
#            12        13         14         15         16         17  \
# col1  0.74402   0.31151   0.315737   0.965141   0.482071   0.541128
# col2  0.00000  33.00000  91.000000  99.000000  85.000000  87.000000
#
#              18         19
# col1   0.571122   0.203215
# col2  59.000000  31.000000

# %%
df
# Out:
#         col1  col2
# 0   0.062312    72
# 1   0.527411    46
# 2   0.927956    44
# 3   0.704199    92
# 4   0.266561    42
# 5   0.811416    75
# 6   0.869957    31
# 7   0.552545    75
# 8   0.912127    29
# 9   0.912776    23
# 10  0.416291    19
# 11  0.742034    41
# 12  0.744020     0
# 13  0.311510    33
# 14  0.315737    91
# 15  0.965141    99
# 16  0.482071    85
# 17  0.541128    87
# 18  0.571122    59
# 19  0.203215    31

# %%
df.dropna(how="any")
# Out:
#         col1  col2
# 0   0.062312    72
# 1   0.527411    46
# 2   0.927956    44
# 3   0.704199    92
# 4   0.266561    42
# 5   0.811416    75
# 6   0.869957    31
# 7   0.552545    75
# 8   0.912127    29
# 9   0.912776    23
# 10  0.416291    19
# 11  0.742034    41
# 12  0.744020     0
# 13  0.311510    33
# 14  0.315737    91
# 15  0.965141    99
# 16  0.482071    85
# 17  0.541128    87
# 18  0.571122    59
# 19  0.203215    31
