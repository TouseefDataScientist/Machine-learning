# %% [markdown]
# ***<center>Name: Aziz ul haq<br>***
# Email: azizulhaqprofessional@gmail.com<br>
# Github: https://github.com/Azizulhaq-professional/Aziz.AI-ML<br>
# Purpose of Document: This is my Porfolio </center>

# %% [markdown]
# **Loading Libraries..**

# %%
#Install Libraries
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing Libraries
import pandas as pd

# %% [markdown]
# **Loading DataSets**

# %%
#loading CSV file
pd .read_csv('Data set.csv')
# Out:
#              Name     Design Gender  Age     Salary
# 0         Mukhtar    Teacher      M  37.0  115000.0
# 1            Aziz    TEacher      M  30.0    3500.0
# 2          Mohsin   Engineer      M  29.0    5000.0
# 3   Naveed Fatima   Analyist      F  30.0    7000.0
# 4           Babar   Engineer      M  25.0  150000.0
# 5            Aqsa  Scientist      F  22.0       NaN
# 6           Rafia   Anaylist      F  29.0    2000.0
# 7           Samra  Scientist      F  26.0  115000.0
# 8            Eman   Engineer      F  28.0    3500.0
# 9        Abdullah    teacher      M  55.0       NaN
# 10          Mosib  Professor      M  60.0    7000.0
# 11          Ahmed    Enginer      M   NaN    9000.0
# 12          Ahsan    Tranier      M  56.0   11000.0
# 13          Wajid    teacher      M  67.0     200.0
# 14          Naeem    Trainer      M  80.0    1600.0
# 15         Qaisar  Professor      M  20.0   17000.0
# 16          Wajid   Engineer      M  85.0   19000.0

# %%
df = pd.read_csv('Data set.csv')

# %% [markdown]
# **Preview the Dataset**

# %%
print (df)
# Out:
#              Name     Design Gender  Age     Salary
# 0         Mukhtar    Teacher      M  37.0  115000.0
# 1            Aziz    TEacher      M  30.0    3500.0
# 2          Mohsin   Engineer      M  29.0    5000.0
# 3   Naveed Fatima   Analyist      F  30.0    7000.0
# 4           Babar   Engineer      M  25.0  150000.0
# 5            Aqsa  Scientist      F  22.0       NaN
# 6           Rafia   Anaylist      F  29.0    2000.0
# 7           Samra  Scientist      F  26.0  115000.0
# 8            Eman   Engineer      F  28.0    3500.0
# 9        Abdullah    teacher      M  55.0       NaN
# 10          Mosib  Professor      M  60.0    7000.0
# 11          Ahmed    Enginer      M   NaN    9000.0
# 12          Ahsan    Tranier      M  56.0   11000.0
# 13          Wajid    teacher      M  67.0     200.0
# 14          Naeem    Trainer      M  80.0    1600.0
# 15         Qaisar  Professor      M  20.0   17000.0
# 16          Wajid   Engineer      M  85.0   19000.0

# %%
#Install Excel Libraries
# %pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd . read_excel ('Data set.xlsx')
# Out:
#              Name     Design Gender  Age     Salary
# 0         Mukhtar    Teacher      M  37.0  115000.0
# 1            Aziz    TEacher      M  30.0    3500.0
# 2          Mohsin   Engineer      M  29.0    5000.0
# 3   Naveed Fatima   Analyist      F  30.0    7000.0
# 4           Babar   Engineer      M  25.0  150000.0
# 5            Aqsa  Scientist      F  22.0       NaN
# 6           Rafia   Anaylist      F  29.0    2000.0
# 7           Samra  Scientist      F  26.0  115000.0
# 8            Eman   Engineer      F  28.0    3500.0
# 9        Abdullah    teacher      M  55.0       NaN
# 10          Mosib  Professor      M  60.0    7000.0
# 11          Ahmed    Enginer      M   NaN    9000.0
# 12          Ahsan    Tranier      M  56.0   11000.0
# 13          Wajid    teacher      M  67.0     200.0
# 14          Naeem    Trainer      M  80.0    1600.0
# 15         Qaisar  Professor      M  20.0   17000.0
# 16          Wajid   Engineer      M  85.0   19000.0

# %%
df.head(2)
# Out:
#       Name   Design Gender  Age     Salary
# 0  Mukhtar  Teacher      M  37.0  115000.0
# 1     Aziz  TEacher      M  30.0    3500.0

# %%
df.tail(3)
# Out:
#       Name     Design Gender  Age    Salary
# 14   Naeem    Trainer      M  80.0   1600.0
# 15  Qaisar  Professor      M  20.0  17000.0
# 16   Wajid   Engineer      M  85.0  19000.0

# %%
df.head(5)
# Out:
#             Name    Design Gender  Age     Salary
# 0        Mukhtar   Teacher      M  37.0  115000.0
# 1           Aziz   TEacher      M  30.0    3500.0
# 2         Mohsin  Engineer      M  29.0    5000.0
# 3  Naveed Fatima  Analyist      F  30.0    7000.0
# 4          Babar  Engineer      M  25.0  150000.0

# %%
df.head()
# Out:
#             Name    Design Gender  Age     Salary
# 0        Mukhtar   Teacher      M  37.0  115000.0
# 1           Aziz   TEacher      M  30.0    3500.0
# 2         Mohsin  Engineer      M  29.0    5000.0
# 3  Naveed Fatima  Analyist      F  30.0    7000.0
# 4          Babar  Engineer      M  25.0  150000.0

# %%
df.loc[2]
# Out:
# Name        Mohsin
# Design    Engineer
# Gender           M
# Age           29.0
# Salary      5000.0
# Name: 2, dtype: object

# %%
df.loc[2:5]
# Out:
#             Name     Design Gender  Age     Salary
# 2         Mohsin   Engineer      M  29.0    5000.0
# 3  Naveed Fatima   Analyist      F  30.0    7000.0
# 4          Babar   Engineer      M  25.0  150000.0
# 5           Aqsa  Scientist      F  22.0       NaN

# %%
df.loc[8:8]
# Out:
#    Name    Design Gender  Age   Salary
# 8  Eman  Engineer      F  28.0  3500.0
