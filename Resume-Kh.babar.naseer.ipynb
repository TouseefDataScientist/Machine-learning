# %% [markdown]
# # Babar Naseer
# **Email:** kh.babar.naseer@outlook.com
# **LinkedIn:** [linkedin.com/in/kh-babar-naseer](https://www.linkedin.com/in/kh-babar-naseer)
# **Mobile:** +92-333-6335727
#
# ---
#
# ## Summary
# Ambitious BS Software Engineering student with a strong foundation in C/C++, Python, and Web Development.
# Passionate about AI, Machine Learning, and Linux. Eager to apply theoretical knowledge to practical projects and contribute to innovative software solutions. Committed to continuous learning and growth in the rapidly evolving field of technology.
#
# ---
#
# ## Education
# - **International Islamic University, Islamabad**
#   *Bachelor of Science in Software Engineering*
#   *Aug. 2023 – May 2028 (Expected)*
#
# - **Punjab Group Of Colleges**
#   *Intermediate in Computer Science (ICS)*
#   *Sep. 2021 – Sep. 2023*
#
# ---
#
# ## Experience
# - **JPMorgan Chase & Co. (Remote)**
#   *Software Engineering Virtual Experience*
#   *Aug. 2024 – Sep. 2024*
#   - Software Development: Participated in a virtual internship program, gaining hands-on experience in software engineering practices used at JPMorgan Chase.
#   - Financial Technology: Explored the intersection of finance and technology, working on projects that simulate real-world challenges in the financial services industry.
#
# ---
#
# ## Projects
# - **Machine Learning Model:**
#   Developed a supervised learning model for regression and classification tasks using Python and popular ML libraries.
#
# - **Web Development Portfolio:**
#   Created a responsive personal portfolio website showcasing projects and skills using HTML5, CSS3, and JavaScript.
#
# - **C++ Data Structures Implementation:**
#   Implemented various data structures and algorithms in C++, demonstrating proficiency in object-oriented programming and problem-solving.
#
# ---
#
# ## Technical Skills
# - **Languages:** C, C++, Python, HTML5, CSS3, JavaScript
# - **Technologies:** Git, Linux, AI/ML frameworks
# - **Areas of Expertise:** Web Development, Artificial Intelligence, Machine Learning, Cloud Computing, Cybersecurity
#
# ---
#
# ## Certifications
# - **Introduction to Cybersecurity:** Cisco (Aug. 2024)
# - **J.P. Morgan - Software Engineering Job Simulation:** Forage (Aug. 2024)
# - **Python from Beginning to Advance:** Udemy (Jun. 2024)
# - **Supervised Machine Learning: Regression and Classification:** DeepLearning.AI (Dec. 2024)
# - **A Practical Introduction to Cloud Computing:** Flackbox
#
# ---
#
# ## Languages
# - **English:** Professional working proficiency
# - **Urdu:** Native or bilingual proficiency
# - **Arabic:** Elementary proficiency
#
# [LinkedIn Profile](https://www.linkedin.com/in/kh-babar-naseer)
# [Email Babar Naseer](mailto:babar.naseer@example.com)
