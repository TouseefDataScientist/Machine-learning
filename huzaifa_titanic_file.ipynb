# %% [markdown]
# <center>
#
# ### Name:  Huzaifa Dad
# ### Email: huzaifadad.abt@gmail.com
# ### Github: https://github.com/HuzaifaDad
# ### Purpose of Document: Data Preprocessing on titanic data file
# </center>

# %% [markdown]
# # Installing Library

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\huzai\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\huzai\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\huzai\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\huzai\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading titanic csv file

# %%
df=pd.read_csv('huzaifa_titanic_data.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Task 01:
# # Remove Name,Ticket,Cabin columns

# %%
df = df.drop(['Name','Ticket','Cabin'], axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %% [markdown]
# # Task 02:
# # Data Wrangling

# %% [markdown]
# # 1. Fill null values

# %%
#check null values in whole data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
#check Age column null values
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
#Fill null values by mean
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Fill null values from Embarked column
df['Embarked'] = df['Embarked'].fillna(df['Fare'].mode()[0])
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df['Embarked'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# # Task 03:
# # Change Gender column to 0 and 1

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df['Sex'].unique())
# Out:
# ['male' 'female']

# %%
df['Sex'] = df['Sex'].map({'male':0,'female':1})
df['Sex']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
df = df.rename(columns={'Sex':'Gender'})

# %%
df['Gender']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Gender, Length: 891, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Gender        Age  SibSp  Parch     Fare  \
# 0              1         0       3       0  22.000000      1      0   7.2500
# 1              2         1       1       1  38.000000      1      0  71.2833
# 2              3         1       3       1  26.000000      0      0   7.9250
# 3              4         1       1       1  35.000000      1      0  53.1000
# 4              5         0       3       0  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2       0  27.000000      0      0  13.0000
# 887          888         1       1       1  19.000000      0      0  30.0000
# 888          889         0       3       1  29.699118      1      2  23.4500
# 889          890         1       1       0  26.000000      0      0  30.0000
# 890          891         0       3       0  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %% [markdown]
# # Task 04:
# # Make new comparison column

# %%
df['Age'] = df['Age'].astype(int)
df['Age']
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    29
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
df['Fare'] = df['Fare'].astype(int)
df['Fare']
# Out:
# 0       7
# 1      71
# 2       7
# 3      53
# 4       8
#        ..
# 886    13
# 887    30
# 888    23
# 889    30
# 890     7
# Name: Fare, Length: 891, dtype: int64

# %%
df['Comparison'] = 'Age:' + df['Age'].astype(str) + ',Fare:' + df['Fare'].astype(str)
df['Comparison']
# Out:
# 0       Age:22,Fare:7
# 1      Age:38,Fare:71
# 2       Age:26,Fare:7
# 3      Age:35,Fare:53
# 4       Age:35,Fare:8
#             ...
# 886    Age:27,Fare:13
# 887    Age:19,Fare:30
# 888    Age:29,Fare:23
# 889    Age:26,Fare:30
# 890     Age:32,Fare:7
# Name: Comparison, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Gender  Age  SibSp  Parch  Fare Embarked  \
# 0              1         0       3       0   22      1      0     7        S
# 1              2         1       1       1   38      1      0    71        C
# 2              3         1       3       1   26      0      0     7        S
# 3              4         1       1       1   35      1      0    53        S
# 4              5         0       3       0   35      0      0     8        S
# ..           ...       ...     ...     ...  ...    ...    ...   ...      ...
# 886          887         0       2       0   27      0      0    13        S
# 887          888         1       1       1   19      0      0    30        S
# 888          889         0       3       1   29      1      2    23        S
# 889          890         1       1       0   26      0      0    30        C
# 890          891         0       3       0   32      0      0     7        Q
#
#          Comparison
# 0     Age:22,Fare:7
# 1    Age:38,Fare:71
# 2     Age:26,Fare:7
# 3    Age:35,Fare:53
# 4     Age:35,Fare:8
# ..              ...
# 886  Age:27,Fare:13
# 887  Age:19,Fare:30
# 888  Age:29,Fare:23
# 889  Age:26,Fare:30
# 890   Age:32,Fare:7
#
# [891 rows x 10 columns]

# %% [markdown]
# # Task 05:
# # Make user defined Function

# %%
def process_titanic_data(df):

    #Task 01: Remove Name,Ticket,Cabin
    df = df.drop(['Name','Ticket','Cabin'], axis=1)

    # Task 2: Fill null values in 'Age' and 'Embarked'
    if 'Age' in df.columns:
        df['Age'] = df['Age'].fillna(df['Age'].mean())
    if 'Embarked' in df.columns:
        df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

    # Task 3: Convert 'Sex' column values
    if 'Sex' in df.columns:
        df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

    # Task 4: Create 'Comparison' column
    if 'Age' in df.columns and 'Fare' in df.columns:
        df['Comparison'] = "Age: " + df['Age'].astype(int).astype(str) + ", Fare: " + df['Fare'].astype(int).astype(str)
    
    return df

# %%
titanic_df = pd.read_csv('huzaifa_titanic_data.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
process_df = process_titanic_data(titanic_df)

# %%
process_df
# Out:
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    0  22.000000      1      0   7.2500
# 1              2         1       1    1  38.000000      1      0  71.2833
# 2              3         1       3    1  26.000000      0      0   7.9250
# 3              4         1       1    1  35.000000      1      0  53.1000
# 4              5         0       3    0  35.000000      0      0   8.0500
# ..           ...       ...     ...  ...        ...    ...    ...      ...
# 886          887         0       2    0  27.000000      0      0  13.0000
# 887          888         1       1    1  19.000000      0      0  30.0000
# 888          889         0       3    1  29.699118      1      2  23.4500
# 889          890         1       1    0  26.000000      0      0  30.0000
# 890          891         0       3    0  32.000000      0      0   7.7500
#
#     Embarked         Comparison
# 0          S   Age: 22, Fare: 7
# 1          C  Age: 38, Fare: 71
# 2          S   Age: 26, Fare: 7
# 3          S  Age: 35, Fare: 53
# 4          S   Age: 35, Fare: 8
# ..       ...                ...
# 886        S  Age: 27, Fare: 13
# 887        S  Age: 19, Fare: 30
# 888        S  Age: 29, Fare: 23
# 889        C  Age: 26, Fare: 30
# 890        Q   Age: 32, Fare: 7
#
# [891 rows x 10 columns]

# %%
process_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# Comparison     0
# dtype: int64

# %%
process_df['Comparison']
# Out:
# 0       Age: 22, Fare: 7
# 1      Age: 38, Fare: 71
# 2       Age: 26, Fare: 7
# 3      Age: 35, Fare: 53
# 4       Age: 35, Fare: 8
#              ...
# 886    Age: 27, Fare: 13
# 887    Age: 19, Fare: 30
# 888    Age: 29, Fare: 23
# 889    Age: 26, Fare: 30
# 890     Age: 32, Fare: 7
# Name: Comparison, Length: 891, dtype: object
