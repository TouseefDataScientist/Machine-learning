# %% [markdown]
# # Babar Naseer
# **Email:** kh.babar.naseer@outlook.com
# **Github:**   [github.com/KhBabarNaseer](https://github.com/KhBabarNaseer)
#
# **Mobile:** +92-333-6335727
#
# **Lab Task:**

# %% [markdown]
# #### Loading Libraries

# %%
#install Libraries
#%pip install pandas

# %%
#import Lib
import pandas as pd

# %% [markdown]
# ##### Loading Datasets

# %%
#Loading CSV File
pd.read_csv("random_employee_data.csv")
# Out:
#        Name Designation  Gender  Age  Salary
# 0   Charlie     Manager    Male   23   78523
# 1      Paul    Engineer    Male   30   63332
# 2    Quincy     Analyst  Female   29  110424
# 3       Bob     Manager    Male   32   31536
# 4    George       Clerk    Male   49   55219
# 5    Edward  Technician    Male   25   30683
# 6     Irene  Technician  Female   54   65454
# 7     Alice  Technician    Male   46  106580
# 8      Liam    Engineer    Male   30   84381
# 9      Mona     Manager  Female   59   50349
# 10   Rachel       Clerk  Female   34   46706
# 11    Diana    Engineer    Male   26   38020
# 12     Jack       Clerk  Female   55   60933
# 13   Olivia       Clerk  Female   22   33221
# 14    Fiona  Technician  Female   24   54126
# 15   Hannah     Manager  Female   59   89088
# 16   Nathan    Engineer    Male   40   36436
# 17    Karen  Technician    Male   29  107164

# %%
df = pd.read_csv("random_employee_data.csv")

# %%
df
# Out:
#        Name Designation  Gender  Age  Salary
# 0   Charlie     Manager    Male   23   78523
# 1      Paul    Engineer    Male   30   63332
# 2    Quincy     Analyst  Female   29  110424
# 3       Bob     Manager    Male   32   31536
# 4    George       Clerk    Male   49   55219
# 5    Edward  Technician    Male   25   30683
# 6     Irene  Technician  Female   54   65454
# 7     Alice  Technician    Male   46  106580
# 8      Liam    Engineer    Male   30   84381
# 9      Mona     Manager  Female   59   50349
# 10   Rachel       Clerk  Female   34   46706
# 11    Diana    Engineer    Male   26   38020
# 12     Jack       Clerk  Female   55   60933
# 13   Olivia       Clerk  Female   22   33221
# 14    Fiona  Technician  Female   24   54126
# 15   Hannah     Manager  Female   59   89088
# 16   Nathan    Engineer    Male   40   36436
# 17    Karen  Technician    Male   29  107164

# %%
#Excel Lib
# %pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel("random_employee_data.xlsx")
# Out:
#        Name Designation  Gender  Age  Salary
# 0   Charlie     Manager    Male   23   78523
# 1      Paul    Engineer    Male   30   63332
# 2    Quincy     Analyst  Female   29  110424
# 3       Bob     Manager    Male   32   31536
# 4    George       Clerk    Male   49   55219
# 5    Edward  Technician    Male   25   30683
# 6     Irene  Technician  Female   54   65454
# 7     Alice  Technician    Male   46  106580
# 8      Liam    Engineer    Male   30   84381
# 9      Mona     Manager  Female   59   50349
# 10   Rachel       Clerk  Female   34   46706
# 11    Diana    Engineer    Male   26   38020
# 12     Jack       Clerk  Female   55   60933
# 13   Olivia       Clerk  Female   22   33221
# 14    Fiona  Technician  Female   24   54126
# 15   Hannah     Manager  Female   59   89088
# 16   Nathan    Engineer    Male   40   36436
# 17    Karen  Technician    Male   29  107164

# %%
df_excel = pd.read_excel("random_employee_data.xlsx")

# %%
df_excel
# Out:
#        Name Designation  Gender  Age  Salary
# 0   Charlie     Manager    Male   23   78523
# 1      Paul    Engineer    Male   30   63332
# 2    Quincy     Analyst  Female   29  110424
# 3       Bob     Manager    Male   32   31536
# 4    George       Clerk    Male   49   55219
# 5    Edward  Technician    Male   25   30683
# 6     Irene  Technician  Female   54   65454
# 7     Alice  Technician    Male   46  106580
# 8      Liam    Engineer    Male   30   84381
# 9      Mona     Manager  Female   59   50349
# 10   Rachel       Clerk  Female   34   46706
# 11    Diana    Engineer    Male   26   38020
# 12     Jack       Clerk  Female   55   60933
# 13   Olivia       Clerk  Female   22   33221
# 14    Fiona  Technician  Female   24   54126
# 15   Hannah     Manager  Female   59   89088
# 16   Nathan    Engineer    Male   40   36436
# 17    Karen  Technician    Male   29  107164

# %%
#Display Top Row
df.head(10)
# Out:
#       Name Designation  Gender  Age  Salary
# 0  Charlie     Manager    Male   23   78523
# 1     Paul    Engineer    Male   30   63332
# 2   Quincy     Analyst  Female   29  110424
# 3      Bob     Manager    Male   32   31536
# 4   George       Clerk    Male   49   55219
# 5   Edward  Technician    Male   25   30683
# 6    Irene  Technician  Female   54   65454
# 7    Alice  Technician    Male   46  106580
# 8     Liam    Engineer    Male   30   84381
# 9     Mona     Manager  Female   59   50349

# %%
#Show Bottom Rows

df.tail()
# Out:
#       Name Designation  Gender  Age  Salary
# 13  Olivia       Clerk  Female   22   33221
# 14   Fiona  Technician  Female   24   54126
# 15  Hannah     Manager  Female   59   89088
# 16  Nathan    Engineer    Male   40   36436
# 17   Karen  Technician    Male   29  107164

# %%
df.tail(0)
# Out:
# Empty DataFrame
# Columns: [Name, Designation, Gender, Age, Salary]
# Index: []

# %%
df.head(8)
# Out:
#       Name Designation  Gender  Age  Salary
# 0  Charlie     Manager    Male   23   78523
# 1     Paul    Engineer    Male   30   63332
# 2   Quincy     Analyst  Female   29  110424
# 3      Bob     Manager    Male   32   31536
# 4   George       Clerk    Male   49   55219
# 5   Edward  Technician    Male   25   30683
# 6    Irene  Technician  Female   54   65454
# 7    Alice  Technician    Male   46  106580

# %%
df.loc[8:9]
# Out:
#    Name Designation  Gender  Age  Salary
# 8  Liam    Engineer    Male   30   84381
# 9  Mona     Manager  Female   59   50349

# %%
# %pip install python-docx
# Out:
# ...
#
# ...

# %%
from docx import Document

# %%
A = Document("WORD.docx")

# %%
import json



# Load and read a JSON file
try:
    with open("sample.json", "r") as file:
        content = file.read()
        if content.strip():  # Check if file is not empty
            data = json.loads(content)
            print(data)
        else:
            print("JSON file is empty")
except FileNotFoundError:
    print("File 'sample.json' not found")
except json.JSONDecodeError as e:
    print(f"Invalid JSON format: {e}")
# Out:
# {'name': 'John Doe', 'age': 30, 'email': 'john.doe@example.com', 'isStudent': False, 'courses': [{'name': 'Mathematics', 'credits': 3}, {'name': 'Computer Science', 'credits': 4}], 'address': {'street': '123 Main St', 'city': 'Springfield', 'zipCode': '12345'}}

# %%
#var = open("sample.json", "r")

# %%
pip install PyPDF2 pdfplumber
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PyPDF2 import PdfReader

from IPython.display import IFrame
file_path = "Pdfsample.pdf"
IFrame(file_path, width=700, height=500)

import pdfplumber

with pdfplumber.open("Pdfsample.pdf") as pdf:
    for page in pdf.pages:
        print(page.extract_text())
# Out:
# If you want to display the contents of these files inline in your notebook, you can use the
# IPython.display module

# %%
reader = PdfReader('Pdfsample.pdf')

# %%
df
# Out:
#        Name Designation  Gender  Age  Salary
# 0   Charlie     Manager    Male   23   78523
# 1      Paul    Engineer    Male   30   63332
# 2    Quincy     Analyst  Female   29  110424
# 3       Bob     Manager    Male   32   31536
# 4    George       Clerk    Male   49   55219
# 5    Edward  Technician    Male   25   30683
# 6     Irene  Technician  Female   54   65454
# 7     Alice  Technician    Male   46  106580
# 8      Liam    Engineer    Male   30   84381
# 9      Mona     Manager  Female   59   50349
# 10   Rachel       Clerk  Female   34   46706
# 11    Diana    Engineer    Male   26   38020
# 12     Jack       Clerk  Female   55   60933
# 13   Olivia       Clerk  Female   22   33221
# 14    Fiona  Technician  Female   24   54126
# 15   Hannah     Manager  Female   59   89088
# 16   Nathan    Engineer    Male   40   36436
# 17    Karen  Technician    Male   29  107164

# %%
df.describe()
# Out:
#              Age         Salary
# count  18.000000      18.000000
# mean   37.000000   63454.166667
# std    13.128326   26898.216340
# min    22.000000   30683.000000
# 25%    26.750000   40191.500000
# 50%    31.000000   58076.000000
# 75%    48.250000   82916.500000
# max    59.000000  110424.000000

# %%
df.shape
# Out:
# (18, 5)

# %%
df["Designation"].unique()
# Out:
# array(['Manager', 'Engineer', 'Analyst', 'Clerk', 'Technician'],
#       dtype=object)

# %%
df["Designation"]
# Out:
# 0        Manager
# 1       Engineer
# 2        Analyst
# 3        Manager
# 4          Clerk
# 5     Technician
# 6     Technician
# 7     Technician
# 8       Engineer
# 9        Manager
# 10         Clerk
# 11      Engineer
# 12         Clerk
# 13         Clerk
# 14    Technician
# 15       Manager
# 16      Engineer
# 17    Technician
# Name: Designation, dtype: object

# %%
#Check for Null Values
df.isnull().sum()
# Out:
# Name           0
# Designation    0
# Gender         0
# Age            0
# Salary         0
# dtype: int64

# %%
#  Check for Null Values in a specific column
# df['Age'].isnull().sum()

# %%
# Fill missing values with the mean of the column
df['Age'].fillna(df['Age'].mean())
# Out:
# 0     23
# 1     30
# 2     29
# 3     32
# 4     49
# 5     25
# 6     54
# 7     46
# 8     30
# 9     59
# 10    34
# 11    26
# 12    55
# 13    22
# 14    24
# 15    59
# 16    40
# 17    29
# Name: Age, dtype: int64

# %%
# Drop rows with missing values
# df.dropna(subset=['Salary'])

# %%
# Drop columns with missing values
# df.dropna(axis=1)
